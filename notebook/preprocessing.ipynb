# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# Gather historical data for TSLA, BND, and SPY from YFinance

# %%
assets = ['TSLA', 'BND', 'SPY']
# Download historical data
data = yf.download(assets, start="2015-01-01", end="2024-10-31")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
data.head()
# Out:
# Price                      Adj Close                             Close  \
# Ticker                           BND         SPY       TSLA        BND
# Date
# 2015-01-02 00:00:00+00:00  63.358757  173.173737  14.620667  82.650002
# 2015-01-05 00:00:00+00:00  63.542767  170.046280  14.006000  82.889999
# 2015-01-06 00:00:00+00:00  63.726715  168.444626  14.085333  83.129997
# 2015-01-07 00:00:00+00:00  63.765030  170.543655  14.063333  83.180000
# 2015-01-08 00:00:00+00:00  63.665379  173.569992  14.041333  83.050003
#
# Price                                                  High              \
# Ticker                            SPY       TSLA        BND         SPY
# Date
# 2015-01-02 00:00:00+00:00  205.429993  14.620667  82.690002  206.880005
# 2015-01-05 00:00:00+00:00  201.720001  14.006000  82.919998  204.369995
# 2015-01-06 00:00:00+00:00  199.820007  14.085333  83.379997  202.720001
# 2015-01-07 00:00:00+00:00  202.309998  14.063333  83.279999  202.720001
# ...

# %%
# Access the closing prices of TSLA
tsla_close = data['Close']['TSLA']

# Access the volume of BND
bnd_volume = data['Volume']['BND']

# %%
tsla_close.head()
# Out:
# Date
# 2015-01-02 00:00:00+00:00    14.620667
# 2015-01-05 00:00:00+00:00    14.006000
# 2015-01-06 00:00:00+00:00    14.085333
# 2015-01-07 00:00:00+00:00    14.063333
# 2015-01-08 00:00:00+00:00    14.041333
# Name: TSLA, dtype: float64

# %%
bnd_volume.head()
# Out:
# Date
# 2015-01-02 00:00:00+00:00    2218800
# 2015-01-05 00:00:00+00:00    5820100
# 2015-01-06 00:00:00+00:00    3887600
# 2015-01-07 00:00:00+00:00    2433400
# 2015-01-08 00:00:00+00:00    1873400
# Name: BND, dtype: int64

# %% [markdown]
#  Clean and Understand the Data

# %%
# Check for missing values
missing_values = data.isnull().sum()
print("Missing values per column:")
missing_values
# Out:
# Missing values per column:
# Price      Ticker
# Adj Close  BND       0
#            SPY       0
#            TSLA      0
# Close      BND       0
#            SPY       0
#            TSLA      0
# High       BND       0
#            SPY       0
#            TSLA      0
# Low        BND       0
#            SPY       0
#            TSLA      0
# Open       BND       0
#            SPY       0
#            TSLA      0
# Volume     BND       0
#            SPY       0
#            TSLA      0
# dtype: int64

# %%
# Forward fill missing values (propagate the last valid value forward)
data.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_8992\1311604818.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)

# %% [markdown]
# Ensure Data Types are Correct

# %%
data1= data.copy()

# %%
# Check data types of each column
data1.dtypes
# Out:
# Price      Ticker
# Adj Close  BND       float64
#            SPY       float64
#            TSLA      float64
# Close      BND       float64
#            SPY       float64
#            TSLA      float64
# High       BND       float64
#            SPY       float64
#            TSLA      float64
# Low        BND       float64
#            SPY       float64
#            TSLA      float64
# Open       BND       float64
#            SPY       float64
#            TSLA      float64
# Volume     BND         int64
#            SPY         int64
#            TSLA        int64
# dtype: object

# %%
data1.to_csv(r'C:\Users\Yibabe\Desktop\10academy_kifiya-AIMweek-11\data\yfinance_data.csv')

# %% [markdown]
# change the columns in to the correct format to access easly in the next analysis

# %%
import pandas as pd

# Load the data with the first three rows as the header
df = pd.read_csv(r'C:\Users\Yibabe\Desktop\10academy_kifiya-AIMweek-11\data\yfinance_data.csv', header=[0, 1, 2])

# %%
# Check the first few rows to understand the data structure
df.head()
# Out:
#                        Price          Adj Close                     \
#                       Ticker                BND                SPY
#                         Date Unnamed: 1_level_2 Unnamed: 2_level_2
# 0  2015-01-02 00:00:00+00:00          63.358757         173.173737
# 1  2015-01-05 00:00:00+00:00          63.542767         170.046280
# 2  2015-01-06 00:00:00+00:00          63.726715         168.444626
# 3  2015-01-07 00:00:00+00:00          63.765030         170.543655
# 4  2015-01-08 00:00:00+00:00          63.665379         173.569992
#
#                                   Close                                        \
#                 TSLA                BND                SPY               TSLA
#   Unnamed: 3_level_2 Unnamed: 4_level_2 Unnamed: 5_level_2 Unnamed: 6_level_2
# 0          14.620667          82.650002         205.429993          14.620667
# 1          14.006000          82.889999         201.720001          14.006000
# ...

# %%
# Flatten the multi-level columns to make it easier to work with
df.columns = [' '.join(col).strip() for col in df.columns.values]

# %%
# Check the structure of the data after flattening the columns
df.head()
# Out:
#            Price Ticker Date  Adj Close BND Unnamed: 1_level_2  \
# 0  2015-01-02 00:00:00+00:00                         63.358757
# 1  2015-01-05 00:00:00+00:00                         63.542767
# 2  2015-01-06 00:00:00+00:00                         63.726715
# 3  2015-01-07 00:00:00+00:00                         63.765030
# 4  2015-01-08 00:00:00+00:00                         63.665379
#
#    Adj Close SPY Unnamed: 2_level_2  Adj Close TSLA Unnamed: 3_level_2  \
# 0                        173.173737                          14.620667
# 1                        170.046280                          14.006000
# 2                        168.444626                          14.085333
# 3                        170.543655                          14.063333
# 4                        173.569992                          14.041333
#
#    Close BND Unnamed: 4_level_2  Close SPY Unnamed: 5_level_2  \
# 0                     82.650002                    205.429993
# ...

# %%
# Access the 'Date' column after flattening the columns
df['Price Ticker Date']
# Out:
# 0       2015-01-02 00:00:00+00:00
# 1       2015-01-05 00:00:00+00:00
# 2       2015-01-06 00:00:00+00:00
# 3       2015-01-07 00:00:00+00:00
# 4       2015-01-08 00:00:00+00:00
#                   ...
# 2469    2024-10-24 00:00:00+00:00
# 2470    2024-10-25 00:00:00+00:00
# 2471    2024-10-28 00:00:00+00:00
# 2472    2024-10-29 00:00:00+00:00
# 2473    2024-10-30 00:00:00+00:00
# Name: Price Ticker Date, Length: 2474, dtype: object

# %% [markdown]
# Convert the Date column to datetime type

# %%
# Ensure Date column is in datetime format
df['Price Ticker Date'] = pd.to_datetime(df['Price Ticker Date'])

# %%
df.head()
# Out:
#           Price Ticker Date  Adj Close BND Unnamed: 1_level_2  \
# 0 2015-01-02 00:00:00+00:00                         63.358757
# 1 2015-01-05 00:00:00+00:00                         63.542767
# 2 2015-01-06 00:00:00+00:00                         63.726715
# 3 2015-01-07 00:00:00+00:00                         63.765030
# 4 2015-01-08 00:00:00+00:00                         63.665379
#
#    Adj Close SPY Unnamed: 2_level_2  Adj Close TSLA Unnamed: 3_level_2  \
# 0                        173.173737                          14.620667
# 1                        170.046280                          14.006000
# 2                        168.444626                          14.085333
# 3                        170.543655                          14.063333
# 4                        173.569992                          14.041333
#
#    Close BND Unnamed: 4_level_2  Close SPY Unnamed: 5_level_2  \
# 0                     82.650002                    205.429993
# ...

# %% [markdown]
# Descriptive Statistics

# %%
# Get descriptive statistics of the dataset
df.describe()
# Out:
#        Adj Close BND Unnamed: 1_level_2  Adj Close SPY Unnamed: 2_level_2  \
# count                       2474.000000                       2474.000000
# mean                          70.089252                        310.253153
# std                            4.889918                        111.250656
# min                           62.637577                        157.328568
# 25%                           66.314087                        214.822369
# 50%                           68.888939                        275.812408
# 75%                           73.807495                        402.297516
# max                           79.812927                        584.590027
#
#        Adj Close TSLA Unnamed: 3_level_2  Close BND Unnamed: 4_level_2  \
# count                        2474.000000                   2474.000000
# mean                          111.438965                     80.316039
# std                           110.120450                      5.097592
# ...

# %%
df1=df.copy()

# %%
df1.columns
# Out:
# Index(['Price Ticker Date', 'Adj Close BND Unnamed: 1_level_2',
#        'Adj Close SPY Unnamed: 2_level_2', 'Adj Close TSLA Unnamed: 3_level_2',
#        'Close BND Unnamed: 4_level_2', 'Close SPY Unnamed: 5_level_2',
#        'Close TSLA Unnamed: 6_level_2', 'High BND Unnamed: 7_level_2',
#        'High SPY Unnamed: 8_level_2', 'High TSLA Unnamed: 9_level_2',
#        'Low BND Unnamed: 10_level_2', 'Low SPY Unnamed: 11_level_2',
#        'Low TSLA Unnamed: 12_level_2', 'Open BND Unnamed: 13_level_2',
#        'Open SPY Unnamed: 14_level_2', 'Open TSLA Unnamed: 15_level_2',
#        'Volume BND Unnamed: 16_level_2', 'Volume SPY Unnamed: 17_level_2',
#        'Volume TSLA Unnamed: 18_level_2'],
#       dtype='object')

# %% [markdown]
# Rename Columns More Readably:

# %%
# Renaming columns for better clarity
df1.rename(columns={
    'Price Ticker Date': 'Date',
    'Adj Close BND Unnamed: 1_level_2': 'Adj Close BND',
    'Adj Close SPY Unnamed: 2_level_2': 'Adj Close SPY',
    'Adj Close TSLA Unnamed: 3_level_2': 'Adj Close TSLA',
    'Close BND Unnamed: 4_level_2': 'Close BND',
    'Close SPY Unnamed: 5_level_2': 'Close SPY',
    'Close TSLA Unnamed: 6_level_2': 'Close TSLA',
    'High BND Unnamed: 7_level_2': 'High BND',
    'High SPY Unnamed: 8_level_2': 'High SPY',
    'High TSLA Unnamed: 9_level_2': 'High TSLA',
    'Low BND Unnamed: 10_level_2': 'Low BND',
    'Low SPY Unnamed: 11_level_2': 'Low SPY',
    'Low TSLA Unnamed: 12_level_2': 'Low TSLA',
    'Open BND Unnamed: 13_level_2': 'Open BND',
    'Open SPY Unnamed: 14_level_2': 'Open SPY',
    'Open TSLA Unnamed: 15_level_2': 'Open TSLA',
    'Volume BND Unnamed: 16_level_2': 'Volume BND',
    'Volume SPY Unnamed: 17_level_2': 'Volume SPY',
    'Volume TSLA Unnamed: 18_level_2': 'Volume TSLA'
}, inplace=True)

# %%
# Check the cleaned column names
df1.columns
# Out:
# Index(['Date', 'Adj Close BND', 'Adj Close SPY', 'Adj Close TSLA', 'Close BND',
#        'Close SPY', 'Close TSLA', 'High BND', 'High SPY', 'High TSLA',
#        'Low BND', 'Low SPY', 'Low TSLA', 'Open BND', 'Open SPY', 'Open TSLA',
#        'Volume BND', 'Volume SPY', 'Volume TSLA'],
#       dtype='object')

# %% [markdown]
# Visualize the Data

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(df1['Date'],df1['Close TSLA'], label='TSLA', color='blue')
plt.plot(df1['Date'], df1['Close BND'], label='BND', color='green')
plt.plot(df1['Date'], df1['Close SPY'], label='SPY', color='red')

plt.title('Closing Prices of TSLA, BND, and SPY')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
# Check the data types and missing values
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2474 entries, 0 to 2473
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            2474 non-null   datetime64[ns, UTC]
#  1   Adj Close BND   2474 non-null   float64
#  2   Adj Close SPY   2474 non-null   float64
#  3   Adj Close TSLA  2474 non-null   float64
#  4   Close BND       2474 non-null   float64
#  5   Close SPY       2474 non-null   float64
#  6   Close TSLA      2474 non-null   float64
#  7   High BND        2474 non-null   float64
#  8   High SPY        2474 non-null   float64
#  9   High TSLA       2474 non-null   float64
#  10  Low BND         2474 non-null   float64
#  11  Low SPY         2474 non-null   float64
#  12  Low TSLA        2474 non-null   float64
#  13  Open BND        2474 non-null   float64
#  14  Open SPY        2474 non-null   float64
#  15  Open TSLA       2474 non-null   float64
# ...

# %%
# Plot histograms of closing prices for TSLA, BND, and SPY
plt.figure(figsize=(15, 6))

plt.subplot(1, 3, 1)
df1['Close TSLA'].hist(bins=50, color='blue', alpha=0.7)
plt.title('TSLA Closing Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.subplot(1, 3, 2)
df1['Close BND'].hist(bins=50, color='green', alpha=0.7)
plt.title('BND Closing Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.subplot(1, 3, 3)
df1['Close SPY'].hist(bins=50, color='red', alpha=0.7)
plt.title('SPY Closing Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
df1.to_csv(r'C:\Users\Yibabe\Desktop\10academy_kifiya-AIMweek-11\data\cleaned_data.csv')

# %%
df1.head()
# Out:
#                        Date  Adj Close BND  Adj Close SPY  Adj Close TSLA  \
# 0 2015-01-02 00:00:00+00:00      63.358757     173.173737       14.620667
# 1 2015-01-05 00:00:00+00:00      63.542767     170.046280       14.006000
# 2 2015-01-06 00:00:00+00:00      63.726715     168.444626       14.085333
# 3 2015-01-07 00:00:00+00:00      63.765030     170.543655       14.063333
# 4 2015-01-08 00:00:00+00:00      63.665379     173.569992       14.041333
#
#    Close BND   Close SPY  Close TSLA   High BND    High SPY  High TSLA  \
# 0  82.650002  205.429993   14.620667  82.690002  206.880005  14.883333
# 1  82.889999  201.720001   14.006000  82.919998  204.369995  14.433333
# 2  83.129997  199.820007   14.085333  83.379997  202.720001  14.280000
# 3  83.180000  202.309998   14.063333  83.279999  202.720001  14.318667
# 4  83.050003  205.899994   14.041333  83.110001  206.160004  14.253333
#
#      Low BND     Low SPY   Low TSLA   Open BND    Open SPY  Open TSLA  \
# ...

# %%
import matplotlib.pyplot as plt
# Try adjusting the bins for finer details
plt.figure(figsize=(15, 6))
plt.subplot(1, 3, 1)
df1['Close TSLA'].hist(bins=100, color='blue', alpha=0.7)  # More bins
plt.title('TSLA Closing Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')

# Repeat for other assets...
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Add density plot over histogram
plt.figure(figsize=(15, 6))

plt.subplot(1, 3, 1)
sns.histplot(df1['Close TSLA'], bins=100, kde=True, color='blue', alpha=0.7)  # KDE line added
plt.title('TSLA Closing Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')

# Repeat for other assets...
plt.tight_layout()
plt.show()

# %%
# Use log scale on y-axis
plt.figure(figsize=(15, 6))

plt.subplot(1, 3, 1)
df1['Close TSLA'].hist(bins=100, color='blue', alpha=0.7)
plt.yscale('log')  # Log scale for better visibility
plt.title('TSLA Closing Price Distribution (Log Scale)')
plt.xlabel('Price')
plt.ylabel('Log Frequency')

# Repeat for other assets...
plt.tight_layout()
plt.show()

# %%
df1['Daily_Return'] = df1['Close TSLA'].pct_change()
df1['Daily_Return'].plot(label='Daily Return')
plt.legend()
plt.show()

# %%
df1['Daily_Return'] = df1['Close BND'].pct_change()
df1['Daily_Return'].plot(label='Daily Return')
plt.show()

# %%
df1['Daily_Return'] = df1['Close SPY'].pct_change()
df1['Daily_Return'].plot(label='Daily Return')
plt.show()

# %% [markdown]
# Seasonality and Trend Analysis

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Ensure 'Date' is set as the index for time series analysis
df1.set_index('Date', inplace=True)  

# Perform seasonal decomposition on TSLA's closing price
# Note: Use 'multiplicative' or 'additive' model based on your data characteristics
decomposition = seasonal_decompose(df1['Close TSLA'], model='multiplicative', period=252)  # 252 trading days per year

# Plot the decomposed components
decomposition.plot()
plt.show()

# %%
# Perform seasonal decomposition on TSLA's closing price
# Note: Use 'multiplicative' or 'additive' model based on your data characteristics
decomposition = seasonal_decompose(df1['Close BND'], model='multiplicative', period=252)  # 252 trading days per year

# Plot the decomposed components
decomposition.plot()
plt.show()

# %%
# Perform seasonal decomposition on TSLA's closing price
# Note: Use 'multiplicative' or 'additive' model based on your data characteristics
decomposition = seasonal_decompose(df1['Close SPY'], model='multiplicative', period=252)  # 252 trading days per year

# Plot the decomposed components
decomposition.plot()
plt.show()
